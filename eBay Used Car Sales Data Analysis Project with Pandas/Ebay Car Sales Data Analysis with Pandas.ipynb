# %% [markdown]
# ## eBay Car Sales Data Analysis with Pandas
# This script takes eBay car sales data from eBay Kleinanzeigen with data originally uploaded to Kaggle. However, the dataset for this analysis is a modified version of the Kaggle data, with data cleaning needing to be applied to the dataset to perform analysis.
#
# The data dictionary provided with data is as follows:
#
# dateCrawled - When this ad was first crawled. All field-values are taken from this date.
# name - Name of the car.
# seller - Whether the seller is private or a dealer.
# offerType - The type of listing
# price - The price on the ad to sell the car.
# abtest - Whether the listing is included in an A/B test.
# vehicleType - The vehicle Type.
# yearOfRegistration - The year in which which year the car was first registered.
# gearbox - The transmission type.
# powerPS - The power of the car in PS.
# model - The car model name.
# kilometer - How many kilometers the car has driven.
# monthOfRegistration - The month in which which year the car was first registered.
# fuelType - What type of fuel the car uses.
# brand - The brand of the car.
# notRepairedDamage - If the car has a damage which is not yet repaired.
# dateCreated - The date on which the eBay listing was created.
# nrOfPictures - The number of pictures in the ad.
# postalCode - The postal code for the location of the vehicle.
# lastSeenOnline - When the crawler saw this ad last online.

# %%
#importing libraries needed for analysis
import numpy as np
import pandas as pd

# %%
#read in the csv file
autos = pd.read_csv('autos.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xdc in position 23: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-13b5b4547728> in <module>
#       1 #read in the csv file
# ----> 2 autos = pd.read_csv('autos.csv')
#
# ...

# %%
#since Unicode error came up, going to try Latin-1 first, and if decode error comes again, then will try Windows-1252
autos = pd.read_csv('autos.csv', encoding ='Latin-1')

# %%
#display autos dataframe
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
#get information on the number of columns, column names, data type of columns, number of rows, etc. in the Autos dataframe
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %%
#get the first five rows of the atos dataframe
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %% [markdown]
# # Initial Observations
# When using .info on the auto dataframe, the datset has 20 columns, most columns are strings since the datatype is shown as an object. The max number of entries is 50,000, and some of the columns have null values since some columns have a max number of values in the 40,000 to 47,500 range. Also, the column names use camelcase, which will make renaming the columns into something more understandable a little harder since spaces can't be replaced with underscores since there are no spaces in the column names.

# %%
#Priting an array of the existing column names
print(autos.columns)
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
#Creating a dictionary of renamed column names
column_name_dict = {
    'dateCrawled': 'date_crawled',
    'name': 'name',
    'seller': 'seller',
    'offerType': 'offer_type',
    'price': 'price',
    'abtest': 'ab_test',
    'vehicleType': 'vehicle_type',
    'yearOfRegistration' : 'registration_year',
    'gearbox' : 'gearbox',
    'powerPS' : 'power_ps',
    'model' : 'model',
    'odometer' : 'odometer',
    'monthOfRegistration' : 'registration_month',
    'fuelType' : 'fuel_type',
    'brand' : 'brand',
    'notRepairedDamage' : 'unrepaired_damage',
    'dateCreated' : 'ad_created',
    'nrOfPictures' : 'num_photos',
    'postalCode' : 'postal_code',
    'lastSeen' : 'last_seen'    
}

#renaming existing columns using the dictionary of updated column names
autos = autos.rename(columns=column_name_dict)

#Using .head() to see the column changes applied to the autos dataframe
autos
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %% [markdown]
# Changes were made to the column names to make them more understandable to an American audience since the column names were originally for a German audience. Some column name changes were notRepairedDamange to unrepaired_damage, dateCreated to ad_created, nrOfPictures to num_of_pictures, etc.

# %%
#Getting descriptive statistics for all columns in autos
autos.describe()
# Out:
#        registration_year      power_ps  registration_month  num_photos  \
# count       50000.000000  50000.000000        50000.000000     50000.0
# mean         2005.073280    116.355920            5.723360         0.0
# std           105.712813    209.216627            3.711984         0.0
# min          1000.000000      0.000000            0.000000         0.0
# 25%          1999.000000     70.000000            3.000000         0.0
# 50%          2003.000000    105.000000            6.000000         0.0
# 75%          2008.000000    150.000000            9.000000         0.0
# max          9999.000000  17700.000000           12.000000         0.0
#
#         postal_code
# count  50000.000000
# mean   50813.627300
# std    25779.747957
# min     1067.000000
# 25%    30451.000000
# 50%    49577.000000
# 75%    71540.000000
# max    99998.000000

# %% [markdown]
# Based on initial review of the descriptive statistics for all columns in autos, only five columns came up. Those five columns have a datatype of int64. The registration_year column has a minimum of 1000, which doesn't make sense since cars didn't exist then and needs to be investigated. The registration_year column has a maximum of 9999, which doesn't make sense since that is in the future. The registration_month column has a minimum of 0, which might be incorrect and needs to be investigated. The num_photos can be dropped since min, max, and mean are all 0, which means none of the listings contained any pictures.
#
# The price and odometer columns are numeric values, however, right now they are strings, so they need to be converted to a numeric dtype in order to get descriptive statistics.
#
# The seller and offer_type columns can be dropped since each column has what appears to be the same value for all rows.

# %%
#Converting price column to a numeric dtype
autos['price'] = autos['price'].str.replace('$','').str.replace(',','').astype(int)

# %%
#Converting odometer column to a numeric dtype
autos['odometer'] = autos['odometer'].str.replace(',','').str.replace('km','').astype(int)

# %%
#Renaming odometer to odometer_km
autos.rename(columns={'odometer': 'odometer_km'}, inplace=True)
autos
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
#Determining unique values in odometer_km
autos['odometer_km'].unique().shape
# Out:
# (13,)

# %%
#Determining unique values in price
autos['price'].unique().shape
# Out:
# (2357,)

# %%
#Descriptive statistics for odometer_km. Lamdba function used to display results without scientific notation and usting f string to print to 1 decimal place
autos['odometer_km'].describe().apply(lambda x: format(x, '.1f'))
# Out:
# count     50000.0
# mean     125732.7
# std       40042.2
# min        5000.0
# 25%      125000.0
# 50%      150000.0
# 75%      150000.0
# max      150000.0
# Name: odometer_km, dtype: object

# %%
#Descriptive statistics for price. Lamdba function used to display results without scientific notation and usting f string to print to 1 decimal place
autos['price'].describe().apply(lambda x: format(x, '.1f'))
# Out:
# count       50000.0
# mean         9840.0
# std        481104.4
# min             0.0
# 25%          1100.0
# 50%          2950.0
# 75%          7200.0
# max      99999999.0
# Name: price, dtype: object

# %% [markdown]
# # Initial observations from shape and describe for odometer_km and price
# For the odometer_km column, there are only 13 unique odometer readings and when looking at the descriptive statistics, 5,000 km might be an outlier due to the large standard deviation of 40042. At 50 percent and 75 percent, the odometer reading is both at 150,000. The average odometer reading is 125,732.7 km. All odometer readings look to be rounded.
#
# For the price column, there are 2357 unique prices and when looking at the descriptive statistics, there are two outliers, with a minimum price of 0 and a maximum price of 99999999, which is odd since the average price is 9,840 and the standard deviation is 481104, which looks to be skewed by the maximum price. All prices look to be rounded.

# %%
#Frequency of unique odometer readings in odometer_km
autos['odometer_km'].value_counts()
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1027
# 5000        967
# 40000       819
# 30000       789
# 20000       784
# 10000       264
# Name: odometer_km, dtype: int64

# %%
#Frequency of unique prices in prices for the first 20 descending since there is thousands of unique prices
autos['price'].value_counts().sort_index(ascending=False).head(20)
# Out:
# 99999999    1
# 27322222    1
# 12345678    3
# 11111111    2
# 10000000    1
# 3890000     1
# 1300000     1
# 1234566     1
# 999999      2
# 999990      1
# 350000      1
# 345000      1
# 299000      1
# 295000      1
# 265000      1
# 259000      1
# 250000      1
# 220000      1
# 198000      1
# 197000      1
# Name: price, dtype: int64

# %%
#Frequency of unique prices in prices_in_$ for the first 20 ascending since there is thousands of unique prices
autos['price'].value_counts().sort_index(ascending=True).head(20)
# Out:
# 0      1421
# 1       156
# 2         3
# 3         1
# 5         2
# 8         1
# 9         1
# 10        7
# 11        2
# 12        3
# 13        2
# 14        1
# 15        2
# 17        3
# 18        1
# 20        4
# 25        5
# 29        1
# 30        7
# 35        1
# 40        6
# 45        4
# 47        1
# 49        4
# 50       49
# 55        2
# 59        1
# 60        9
# 65        5
# 66        1
# 70       10
# 75        5
# 79        1
# 80       15
# 89        1
# 90        5
# 99       19
# 100     134
# 110       3
# 111       2
# 115       2
# 117       1
# 120      39
# 122       1
# 125       8
# 129       1
# 130      15
# 135       1
# 139       1
# 140       9
# Name: price, dtype: int64

# %% [markdown]
# There are a number of listings with prices below $30, including about 1,500 at $0. There are also a small number of listings with very high values, including 14 at around or over $1 million.
#
# Given that eBay is an auction site, there could legitimately be listings where the cars are for bid (and not a buy it now listing) and where the opening bid is $1. We will keep the $1 items, but remove anything above $350,000, since it seems that prices increase steadily to that number and then jump up to less realistic numbers.

# %%
#Removing prices that are above $350,000
autos = autos[autos['price'].between(1,350000)]

#Descriptive statistics for the updated version of the price column
autos["price"].describe()
# Out:
# count     48565.000000
# mean       5888.935591
# std        9059.854754
# min           1.000000
# 25%        1200.000000
# 50%        3000.000000
# 75%        7490.000000
# max      350000.000000
# Name: price, dtype: float64

# %% [markdown]
# # Exploring the date columns
# There are a number of columns with date information:
#
# - date_crawled
# - registration_month
# - registration_year
# - ad_created
# - last_seen
#
# These are a combination of dates that were crawled, and dates with meta-information from the crawler. The non-registration dates are stored as strings.
#
# We'll explore each of these columns to learn more about the listings.

# %%
#Exploring the date formatting of date_crawled, ad_created, and last_seen
autos[['date_crawled','ad_created','last_seen']][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %%
#Since the first 10 characters in each of the columns represents the day, we can extract the date values
print(autos['date_crawled'].str[:10])
print('\n')
print(autos['ad_created'].str[:10])
print('\n')
print(autos['last_seen'].str[:10])
# Out:
# 0        2016-03-26
# 1        2016-04-04
# 2        2016-03-26
# 3        2016-03-12
# 4        2016-04-01
#             ...
# 49995    2016-03-27
# 49996    2016-03-28
# 49997    2016-04-02
# 49998    2016-03-08
# 49999    2016-03-14
# Name: date_crawled, Length: 48565, dtype: object
#
#
# 0        2016-03-26
# 1        2016-04-04
# 2        2016-03-26
# 3        2016-03-12
# 4        2016-04-01
#             ...
# 49995    2016-03-27
# 49996    2016-03-28
# 49997    2016-04-02
# 49998    2016-03-08
# 49999    2016-03-13
# Name: ad_created, Length: 48565, dtype: object
#
#
# 0        2016-04-06
# 1        2016-04-06
# 2        2016-04-06
# 3        2016-03-15
# 4        2016-04-01
#             ...
# 49995    2016-04-01
# 49996    2016-04-02
# 49997    2016-04-04
# 49998    2016-04-05
# 49999    2016-04-06
# Name: last_seen, Length: 48565, dtype: object

# %%
#Calculate the distribution of values in date_crawled
autos['date_crawled'].str[:10].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 2016-03-05    0.025327
# 2016-03-06    0.014043
# 2016-03-07    0.036014
# 2016-03-08    0.033296
# 2016-03-09    0.033090
# 2016-03-10    0.032184
# 2016-03-11    0.032575
# 2016-03-12    0.036920
# 2016-03-13    0.015670
# 2016-03-14    0.036549
# 2016-03-15    0.034284
# 2016-03-16    0.029610
# 2016-03-17    0.031628
# 2016-03-18    0.012911
# 2016-03-19    0.034778
# 2016-03-20    0.037887
# 2016-03-21    0.037373
# 2016-03-22    0.032987
# 2016-03-23    0.032225
# 2016-03-24    0.029342
# 2016-03-25    0.031607
# 2016-03-26    0.032204
# 2016-03-27    0.031092
# 2016-03-28    0.034860
# 2016-03-29    0.034099
# 2016-03-30    0.033687
# 2016-03-31    0.031834
# 2016-04-01    0.033687
# 2016-04-02    0.035478
# 2016-04-03    0.038608
# 2016-04-04    0.036487
# 2016-04-05    0.013096
# 2016-04-06    0.003171
# 2016-04-07    0.001400
# Name: date_crawled, dtype: float64

# %% [markdown]
# Looks like the site was crawled daily over roughly a one month period in March and April 2016. The distribution of listings crawled on each day is roughly uniform.

# %%
#Calculate the distribution of values in ad_created
autos['ad_created'].str[:10].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 2015-06-11    0.000021
# 2015-08-10    0.000021
# 2015-09-09    0.000021
# 2015-11-10    0.000021
# 2015-12-05    0.000021
#                 ...
# 2016-04-03    0.038855
# 2016-04-04    0.036858
# 2016-04-05    0.011819
# 2016-04-06    0.003253
# 2016-04-07    0.001256
# Name: ad_created, Length: 76, dtype: float64

# %% [markdown]
# There is a large variety of ad created dates. Most fall within 1-2 months of the listing date, but a few are quite old, with the oldest at around 9 months.

# %%
#Calculate the distribution of values in last_seen
autos['last_seen'].str[:10].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 2016-03-05    0.001071
# 2016-03-06    0.004324
# 2016-03-07    0.005395
# 2016-03-08    0.007413
# 2016-03-09    0.009595
# 2016-03-10    0.010666
# 2016-03-11    0.012375
# 2016-03-12    0.023783
# 2016-03-13    0.008895
# 2016-03-14    0.012602
# 2016-03-15    0.015876
# 2016-03-16    0.016452
# 2016-03-17    0.028086
# 2016-03-18    0.007351
# 2016-03-19    0.015834
# 2016-03-20    0.020653
# 2016-03-21    0.020632
# 2016-03-22    0.021373
# 2016-03-23    0.018532
# 2016-03-24    0.019767
# 2016-03-25    0.019211
# 2016-03-26    0.016802
# 2016-03-27    0.015649
# 2016-03-28    0.020859
# 2016-03-29    0.022341
# 2016-03-30    0.024771
# 2016-03-31    0.023783
# 2016-04-01    0.022794
# 2016-04-02    0.024915
# 2016-04-03    0.025203
# 2016-04-04    0.024483
# 2016-04-05    0.124761
# 2016-04-06    0.221806
# 2016-04-07    0.131947
# Name: last_seen, dtype: float64

# %% [markdown]
# The crawler recorded the date it last saw any listing, which allows us to determine on what day a listing was removed, presumably because the car was sold.
#
# The last three days contain a disproportionate amount of 'last seen' values. Given that these are 6-10x the values from the previous days, it's unlikely that there was a massive spike in sales, and more likely that these values are to do with the crawling period ending and don't indicate car sales.

# %%
#Descriptive statistics for registration_year
autos['registration_year'].describe()
# Out:
# count    48565.000000
# mean      2004.755421
# std         88.643887
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# The year that the car was first registered will likely indicate the age of the car. Looking at this column, we note some odd values. The minimum value is 1000, long before cars were invented and the maximum is 9999, many years into the future.

# %%
#Frequency of registration years for the first 30 descending
autos['registration_year'].value_counts().sort_index(ascending=False).head(30)
# Out:
# 9999       3
# 9000       1
# 8888       1
# 6200       1
# 5911       1
# 5000       4
# 4800       1
# 4500       1
# 4100       1
# 2800       1
# 2019       2
# 2018     470
# 2017    1392
# 2016    1220
# 2015     392
# 2014     663
# 2013     803
# 2012    1310
# 2011    1623
# 2010    1589
# 2009    2085
# 2008    2215
# 2007    2277
# 2006    2670
# 2005    2936
# 2004    2703
# 2003    2699
# 2002    2486
# 2001    2636
# 2000    3156
# Name: registration_year, dtype: int64

# %%
#Frequency of registration years for the first 30 aescending
autos['registration_year'].value_counts().sort_index(ascending=True).head(30)
# Out:
# 1000     1
# 1001     1
# 1111     1
# 1800     2
# 1910     5
# 1927     1
# 1929     1
# 1931     1
# 1934     2
# 1937     4
# 1938     1
# 1939     1
# 1941     2
# 1943     1
# 1948     1
# 1950     3
# 1951     2
# 1952     1
# 1953     1
# 1954     2
# 1955     2
# 1956     4
# 1957     2
# 1958     4
# 1959     6
# 1960    23
# 1961     6
# 1962     4
# 1963     8
# 1964    12
# Name: registration_year, dtype: int64

# %% [markdown]
# # Determining Registration Data to Use
# Because a car can't be first registered before the listing was seen, any vehicle with a registration year above 2016 is definitely inaccurate. Determining the earliest valid year is more difficult. Realistically, it could be somewhere in the first few decades of the 1900s.
#
# One option is to remove the listings with these values. Let's determine what percentage of our data has invalid values in this column:

# %%
#Determining registration yeaers that fall outside 1900-2016. ~in front of the autos dataframe is equivalent to not, so this expression will give the percentage of registration years outside the 1900-2016 range. 
(~autos["registration_year"].between(1900,2016)).sum() / autos.shape[0]
# Out:
# 0.038793369710697

# %% [markdown]
# Given that this is less than 4% of our data, we will remove these rows.

# %%
#Removing registration years before 1900 and after 2016
autos = autos[autos['registration_year'].between(1900,2016)]

#Calculate the distribution of values in the updated registration_year column
autos['registration_year'].value_counts(normalize=True).head(10)
# Out:
# 2000    0.067608
# 2005    0.062895
# 1999    0.062060
# 2004    0.057904
# 2003    0.057818
# 2006    0.057197
# 2001    0.056468
# 2002    0.053255
# 1998    0.050620
# 2007    0.048778
# Name: registration_year, dtype: float64

# %% [markdown]
# It appears that most of the vehicles were first registered in the past 20 years.

# %% [markdown]
# # Exploring car brands
# This section will aggregate some of the car brands in the listings to explore variations across different car brands.

# %%
#Determining the unique car brands that are for sale
autos['brand'].unique()
# Out:
# array(['peugeot', 'bmw', 'volkswagen', 'smart', 'ford', 'chrysler',
#        'seat', 'renault', 'mercedes_benz', 'audi', 'sonstige_autos',
#        'opel', 'mazda', 'porsche', 'mini', 'toyota', 'dacia', 'nissan',
#        'jeep', 'saab', 'volvo', 'mitsubishi', 'jaguar', 'fiat', 'skoda',
#        'subaru', 'kia', 'citroen', 'chevrolet', 'hyundai', 'honda',
#        'daewoo', 'suzuki', 'trabant', 'land_rover', 'alfa_romeo', 'lada',
#        'rover', 'daihatsu', 'lancia'], dtype=object)

# %%
#Determining the counts for each car brand for sale with values normalized to represent percentage
autos['brand'].value_counts(normalize = True)
# Out:
# volkswagen        0.211264
# bmw               0.110045
# opel              0.107581
# mercedes_benz     0.096463
# audi              0.086566
# ford              0.069900
# renault           0.047150
# peugeot           0.029841
# fiat              0.025642
# seat              0.018273
# skoda             0.016409
# nissan            0.015274
# mazda             0.015188
# smart             0.014160
# citroen           0.014010
# toyota            0.012703
# hyundai           0.010025
# sonstige_autos    0.009811
# volvo             0.009147
# mini              0.008762
# mitsubishi        0.008226
# honda             0.007840
# kia               0.007069
# alfa_romeo        0.006641
# porsche           0.006127
# suzuki            0.005934
# chevrolet         0.005698
# chrysler          0.003513
# dacia             0.002635
# daihatsu          0.002506
# jeep              0.002271
# subaru            0.002142
# land_rover        0.002099
# saab              0.001649
# ...

# %% [markdown]
# German manufacturers represent four out of the top five brands, almost 50% of the overall listings. Volkswagen is by far the most popular brand, with approximately double the cars for sale of the next two brands combined.
#
# There are lots of brands that don't have a significant percentage of listings, so we will limit our analysis to brands representing more than 5% of total listings.

# %%
#Capturing brands with > 5% listings into a list
brand_counts = autos["brand"].value_counts(normalize=True)
common_brands = brand_counts[brand_counts > .05].index
print(common_brands)
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford'], dtype='object')

# %%
brand_mean_prices = {}

for brand in common_brands:
    brand_only = autos[autos["brand"] == brand]
    mean_price = brand_only["price"].mean()
    brand_mean_prices[brand] = int(mean_price)

brand_mean_prices
# Out:
# {'volkswagen': 5402,
#  'bmw': 8332,
#  'opel': 2975,
#  'mercedes_benz': 8628,
#  'audi': 9336,
#  'ford': 3749}

# %% [markdown]
# Of the top 5 brands, there is a distinct price gap:
#
# Audi, BMW and Mercedes Benz are more expensive
# Ford and Opel are less expensive
# Volkswagen is in between - this may explain its popularity, it may be a 'best of 'both worlds' option.

# %% [markdown]
# # Exploring Kilometers of top brands

# %%
#Creating a dataframe of the top brands by mean price
bmp_series = pd.Series(brand_mean_prices)
pd.DataFrame(bmp_series, columns=["mean_price"])
# Out:
#                mean_price
# volkswagen           5402
# bmw                  8332
# opel                 2975
# mercedes_benz        8628
# audi                 9336
# ford                 3749

# %%
brand_mean_km = {}

for brand in common_brands:
    brand_only = autos[autos["brand"] == brand]
    mean_km = brand_only["odometer_km"].mean()
    brand_mean_km[brand] = int(mean_km)

mean_km = pd.Series(brand_mean_km).sort_values(ascending=False)
mean_prices = pd.Series(brand_mean_prices).sort_values(ascending=False)

# %%
#Creating a dataframe of the top brands by mean kilometers
brand_info = pd.DataFrame(mean_km,columns=['mean_km'])
brand_info
# Out:
#                mean_km
# bmw             132572
# mercedes_benz   130788
# opel            129310
# audi            129157
# volkswagen      128707
# ford            124266

# %%
#Adding a new mean_price column to the brand_info dataframe
brand_info["mean_price"] = mean_prices
brand_info
# Out:
#                mean_km  mean_price
# bmw             132572        8332
# mercedes_benz   130788        8628
# opel            129310        2975
# audi            129157        9336
# volkswagen      128707        5402
# ford            124266        3749

# %% [markdown]
# The range of car mileages does not vary as much as the prices do by brand, instead all falling within 10% for the top brands. There is a slight trend to the more expensive vehicles having higher mileage, with the less expensive vehicles having lower mileage.
